# %% [markdown]
# ## Homework: Deep Jazz

# %%
import numpy as np
from music21 import stream, midi, tempo, note

from grammar import unparse_grammar
from preprocess import get_musical_data, get_corpus_data

from qa import prune_grammar, prune_notes, clean_up_notes
from generator import __sample, __generate_grammar, __predict

# %%
N_epochs = 128  # default
data_fn = 'midi/' + 'original_metheny.mid'  # 'And Then I Knew' by Pat Metheny
out_fn = 'midi/' 'deepjazz_on_metheny...' + str(N_epochs)

# %%
max_len = 20
max_tries = 1000
diversity = 0.5

# musical settings
bpm = 130

# get data
chords, abstract_grammars = get_musical_data(data_fn)
corpus, values, val_indices, indices_val = get_corpus_data(abstract_grammars)
print('corpus length:', len(corpus))
print('total # of values:', len(values))
# Out:
# corpus length: 193
# total # of values: 78

# %%
chords[0]
# Out:
# [<music21.instrument.Piano Piano>,
#  <music21.tempo.MetronomeMark Quarter=112.0>,
#  <music21.key.Key of G major>,
#  <music21.meter.TimeSignature 4/4>]

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM

def get_keras_model(max_len, N_values):
    # build a 2 stacked LSTM
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(max_len, N_values)))
    model.add(Dropout(0.2))
    model.add(LSTM(128, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(N_values))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    return model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Task

# %% [markdown]
# Replace previous model with equivalent in prettytensor or tf.slim
#
# Try to make you code as compact as possible

# %%
class DeepJazz:
    def __init__(max_len, N_values):
        self.max_len = max_len
        self.N_values = N_values
        self.dropout = tf.constant(0.2)
        
        self.x = tf.placeholder(tf.float32, shape=[None, max_len, N_values], name='x')
        self.y = tf.placeholder(tf.float32, [None, self.N_values], name = 'y')

        self.build()
        self.sess = tf.Session()
    
    def build():
        reset_graph()
        
        cell1 = tf.contrib.rnn.BasicLSTMCell(128)
        cell2 = tf.contrib.rnn.BasicLSTMCell(128)

        cell = tf.nn.rnn_cell.MultiRNNCell([cell1, cell2])
        cell = tf.nn.rnn_cell.DropoutWrapper(cell, input_keep_prob=self.dropout)
            
        init_state = cell.zero_state(batch_size, tf.float32)
        rnn_outputs, final_state = tf.nn.dynamic_rnn(cell, self.x)
      
        logits = tf.contrib.layers.fully_connected(run_outputs, N_values, biases_initializer=tf.constant_initializer(0.0))
        self.predictions = tf.nn.softmax(logits)

        self.loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits, self.y))
    
    def create_batches(X, y, batch_size, epochs):
        indices = np.array(range(X.shape[0]))
        for i in range(epochs):
            cur_indeces = np.random_choice(indices, batch_size, replace=False)
            yield X[cur_indeces], y[cur_indeces]
    
    def fit(X, y, batch_size, epochs):
        global_step = tf.Variable(initial_value=0, name='global_step', trainable=False)
        optimizer = tf.train.RMSPropOptimizer(learning_rate=1e-4).minimize(self.loss, global_step=global_step)
        
        self.sess.run(tf.global_variables_initializer())
        for x_batch, y_batch in self.create_batches(X, y, batch_size, epochs):
            dict_ = {self.x: x_batch, self.y: y_batch}
            _, loss, num = self.sess.run([optimizer, self.loss, global_step]. dict_)
            if num % 1 == 0:
                print('num: {}; loss: {}'.format(num, loss))
        
    def predict(x, verbose):
        dict_ = {self.x: x}
        return sess.run([self.predictions], dict_)

# %%
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.estimator import regression
import tflearn

def get_pretty_tensor_model(max_len, N_values):
    in_ = input_data(shape=[None, max_len, N_values], name='input')
    layer1 = tflearn.layers.recurrent.lstm(in_, 128, return_seq=True)
    dropout1 = dropout(layer1, 0.2)
    layer2 = tflearn.layers.recurrent.lstm(dropout1, 128)
    dropout2 = dropout(layer2, 0.2)
    fc = fully_connected(dropout2, N_values, activation='softmax')
    
    reg = regression(fc, optimizer='rmsprop', loss='categorical_crossentropy')
    model = tflearn.DNN(reg)
#     model = Sequential()
#     model.add(LSTM(128, return_sequences=True, input_shape=(max_len, N_values)))
#     model.add(Dropout(0.2))
#     model.add(LSTM(128, return_sequences=False))
#     model.add(Dropout(0.2))
#     model.add(Dense(N_values))
#     model.add(Activation('softmax'))

#     model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

    model.rpredict = model.predict
    model.predict = lambda x, **kwargs: model.rpredict(x)
    return model
# Out:
# hdf5 is not supported on this machine (please install/reinstall h5py for optimal experience)

# %%
get_model = get_pretty_tensor_model #get_keras_model # get_pretty_tensor_model

# %%
import numpy as np

''' Build a 2-layer LSTM from a training corpus '''


def build_model(corpus, val_indices, max_len, N_epochs=128):
    # number of different values or words in corpus
    N_values = len(set(corpus))

    # cut the corpus into semi-redundant sequences of max_len values
    step = 3
    sentences = []
    next_values = []
    for i in range(0, len(corpus) - max_len, step):
        sentences.append(corpus[i: i + max_len])
        next_values.append(corpus[i + max_len])
    print('nb sequences:', len(sentences))

    # transform data into binary matrices
    X = np.zeros((len(sentences), max_len, N_values), dtype=np.bool)
    y = np.zeros((len(sentences), N_values), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, val in enumerate(sentence):
            X[i, t, val_indices[val]] = 1
        y[i, val_indices[next_values[i]]] = 1

    model = get_model(max_len, N_values)
    model.fit(X, y, batch_size=128, n_epoch=N_epochs)

    return model

# %%
# build model
model = build_model(corpus=corpus, val_indices=val_indices,
                         max_len=max_len, N_epochs=N_epochs)

# set up audio stream
out_stream = stream.Stream()

# generation loop
curr_offset = 0.0
loopEnd = len(chords)
for loopIndex in range(1, loopEnd):
    # get chords from file
    curr_chords = stream.Voice()
    for j in chords[loopIndex]:
        curr_chords.insert((j.offset % 4), j)

    # generate grammar
    curr_grammar = __generate_grammar(model=model, corpus=corpus,
                                      abstract_grammars=abstract_grammars,
                                      values=values, val_indices=val_indices,
                                      indices_val=indices_val,
                                      max_len=max_len, max_tries=max_tries,
                                      diversity=diversity)

    curr_grammar = curr_grammar.replace(' A', ' C').replace(' X', ' C')

    # Pruning #1: smoothing measure
    curr_grammar = prune_grammar(curr_grammar)

    # Get notes from grammar and chords
    curr_notes = unparse_grammar(curr_grammar, curr_chords)

    # Pruning #2: removing repeated and too close together notes
    curr_notes = prune_notes(curr_notes)

    # quality assurance: clean up notes
    curr_notes = clean_up_notes(curr_notes)

    # print # of notes in curr_notes
    print('After pruning: %s notes' % (len([i for i in curr_notes
                                            if isinstance(i, note.Note)])))

    # insert into the output stream
    for m in curr_notes:
        out_stream.insert(curr_offset + m.offset, m)
    for mc in curr_chords:
        out_stream.insert(curr_offset + mc.offset, mc)

    curr_offset += 4.0

out_stream.insert(0.0, tempo.MetronomeMark(number=bpm))

# Play the final stream through output (see 'play' lambda function above)
play = lambda x: midi.realtime.StreamPlayer(x).play()
play(out_stream)

# save stream
mf = midi.translate.streamToMidiFile(out_stream)
mf.open(out_fn, 'wb')
mf.write()
mf.close()
# Out:
# nb sequences: 58
# ---------------------------------
# Run id: P8D9YJ
# Log directory: /tmp/tflearn_logs/
# WARNING:tensorflow:Error encountered when serializing layer_tensor/LSTM.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'list' object has no attribute 'name'
# WARNING:tensorflow:Error encountered when serializing layer_tensor/Dropout.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'list' object has no attribute 'name'
# ---------------------------------
# Training samples: 58
# Validation samples: 0
# --
# Training Step: 1  | time: 0.452s
# | RMSProp | epoch: 001 | loss: 0.00000 -- iter: 58/58
# --
# Training Step: 2  | total loss: 3.92221 | time: 0.097s
# | RMSProp | epoch: 002 | loss: 3.92221 -- iter: 58/58
# --
# Training Step: 3  | total loss: 4.27740 | time: 0.086s
# | RMSProp | epoch: 003 | loss: 4.27740 -- iter: 58/58
# --
# Training Step: 4  | total loss: 4.33599 | time: 0.093s
# | RMSProp | epoch: 004 | loss: 4.33599 -- iter: 58/58
# --
# Training Step: 5  | total loss: 4.35001 | time: 0.092s
# | RMSProp | epoch: 005 | loss: 4.35001 -- iter: 58/58
# --
# Training Step: 6  | total loss: 4.35375 | time: 0.086s
# | RMSProp | epoch: 006 | loss: 4.35375 -- iter: 58/58
# --
# Training Step: 7  | total loss: 4.35495 | time: 0.086s
# | RMSProp | epoch: 007 | loss: 4.35495 -- iter: 58/58
# --
# Training Step: 8  | total loss: 4.35593 | time: 0.091s
# | RMSProp | epoch: 008 | loss: 4.35593 -- iter: 58/58
# --
# Training Step: 9  | total loss: 4.35652 | time: 0.090s
# | RMSProp | epoch: 009 | loss: 4.35652 -- iter: 58/58
# --
# Training Step: 10  | total loss: 4.35648 | time: 0.090s
# | RMSProp | epoch: 010 | loss: 4.35648 -- iter: 58/58
# --
# Training Step: 11  | total loss: 4.35610 | time: 0.087s
# | RMSProp | epoch: 011 | loss: 4.35610 -- iter: 58/58
# --
# Training Step: 12  | total loss: 4.35651 | time: 0.100s
# | RMSProp | epoch: 012 | loss: 4.35651 -- iter: 58/58
# --
# Training Step: 13  | total loss: 4.35605 | time: 0.090s
# | RMSProp | epoch: 013 | loss: 4.35605 -- iter: 58/58
# --
# Training Step: 14  | total loss: 4.35602 | time: 0.114s
# | RMSProp | epoch: 014 | loss: 4.35602 -- iter: 58/58
# --
# Training Step: 15  | total loss: 4.35622 | time: 0.111s
# | RMSProp | epoch: 015 | loss: 4.35622 -- iter: 58/58
# --
# Training Step: 16  | total loss: 4.35571 | time: 0.103s
# | RMSProp | epoch: 016 | loss: 4.35571 -- iter: 58/58
# --
# Training Step: 17  | total loss: 4.35580 | time: 0.104s
# | RMSProp | epoch: 017 | loss: 4.35580 -- iter: 58/58
# --
# Training Step: 18  | total loss: 4.35591 | time: 0.101s
# | RMSProp | epoch: 018 | loss: 4.35591 -- iter: 58/58
# --
# Training Step: 19  | total loss: 4.35579 | time: 0.102s
# | RMSProp | epoch: 019 | loss: 4.35579 -- iter: 58/58
# --
# Training Step: 20  | total loss: 4.35568 | time: 0.100s
# | RMSProp | epoch: 020 | loss: 4.35568 -- iter: 58/58
# --
# Training Step: 21  | total loss: 4.35567 | time: 0.114s
# | RMSProp | epoch: 021 | loss: 4.35567 -- iter: 58/58
# --
# Training Step: 22  | total loss: 4.35543 | time: 0.118s
# | RMSProp | epoch: 022 | loss: 4.35543 -- iter: 58/58
# --
# Training Step: 23  | total loss: 4.35541 | time: 0.088s
# | RMSProp | epoch: 023 | loss: 4.35541 -- iter: 58/58
# --
# Training Step: 24  | total loss: 4.35531 | time: 0.094s
# | RMSProp | epoch: 024 | loss: 4.35531 -- iter: 58/58
# --
# Training Step: 25  | total loss: 4.35525 | time: 0.095s
# | RMSProp | epoch: 025 | loss: 4.35525 -- iter: 58/58
# --
# Training Step: 26  | total loss: 4.35516 | time: 0.094s
# | RMSProp | epoch: 026 | loss: 4.35516 -- iter: 58/58
# --
# Training Step: 27  | total loss: 4.35532 | time: 0.094s
# | RMSProp | epoch: 027 | loss: 4.35532 -- iter: 58/58
# --
# Training Step: 28  | total loss: 4.35551 | time: 0.095s
# | RMSProp | epoch: 028 | loss: 4.35551 -- iter: 58/58
# --
# Training Step: 29  | total loss: 4.35536 | time: 0.096s
# | RMSProp | epoch: 029 | loss: 4.35536 -- iter: 58/58
# --
# Training Step: 30  | total loss: 4.35530 | time: 0.092s
# | RMSProp | epoch: 030 | loss: 4.35530 -- iter: 58/58
# --
# Training Step: 31  | total loss: 4.35523 | time: 0.098s
# | RMSProp | epoch: 031 | loss: 4.35523 -- iter: 58/58
# --
# Training Step: 32  | total loss: 4.35515 | time: 0.111s
# | RMSProp | epoch: 032 | loss: 4.35515 -- iter: 58/58
# --
# Training Step: 33  | total loss: 4.35480 | time: 0.099s
# | RMSProp | epoch: 033 | loss: 4.35480 -- iter: 58/58
# --
# Training Step: 34  | total loss: 4.35474 | time: 0.089s
# | RMSProp | epoch: 034 | loss: 4.35474 -- iter: 58/58
# --
# Training Step: 35  | total loss: 4.35460 | time: 0.092s
# | RMSProp | epoch: 035 | loss: 4.35460 -- iter: 58/58
# --
# Training Step: 36  | total loss: 4.35459 | time: 0.088s
# | RMSProp | epoch: 036 | loss: 4.35459 -- iter: 58/58
# --
# Training Step: 37  | total loss: 4.35453 | time: 0.089s
# | RMSProp | epoch: 037 | loss: 4.35453 -- iter: 58/58
# --
# Training Step: 38  | total loss: 4.35440 | time: 0.095s
# | RMSProp | epoch: 038 | loss: 4.35440 -- iter: 58/58
# --
# Training Step: 39  | total loss: 4.35418 | time: 0.092s
# | RMSProp | epoch: 039 | loss: 4.35418 -- iter: 58/58
# --
# Training Step: 40  | total loss: 4.35399 | time: 0.091s
# | RMSProp | epoch: 040 | loss: 4.35399 -- iter: 58/58
# --
# Training Step: 41  | total loss: 4.35391 | time: 0.089s
# | RMSProp | epoch: 041 | loss: 4.35391 -- iter: 58/58
# --
# Training Step: 42  | total loss: 4.35369 | time: 0.091s
# | RMSProp | epoch: 042 | loss: 4.35369 -- iter: 58/58
# --
# Training Step: 43  | total loss: 4.35344 | time: 0.104s
# | RMSProp | epoch: 043 | loss: 4.35344 -- iter: 58/58
# --
# Training Step: 44  | total loss: 4.35324 | time: 0.101s
# | RMSProp | epoch: 044 | loss: 4.35324 -- iter: 58/58
# --
# Training Step: 45  | total loss: 4.35306 | time: 0.098s
# | RMSProp | epoch: 045 | loss: 4.35306 -- iter: 58/58
# --
# Training Step: 46  | total loss: 4.35282 | time: 0.090s
# | RMSProp | epoch: 046 | loss: 4.35282 -- iter: 58/58
# --
# Training Step: 47  | total loss: 4.35251 | time: 0.089s
# | RMSProp | epoch: 047 | loss: 4.35251 -- iter: 58/58
# --
# Training Step: 48  | total loss: 4.35230 | time: 0.088s
# | RMSProp | epoch: 048 | loss: 4.35230 -- iter: 58/58
# --
# Training Step: 49  | total loss: 4.35236 | time: 0.092s
# | RMSProp | epoch: 049 | loss: 4.35236 -- iter: 58/58
# --
# Training Step: 50  | total loss: 4.35209 | time: 0.089s
# | RMSProp | epoch: 050 | loss: 4.35209 -- iter: 58/58
# --
# Training Step: 51  | total loss: 4.35205 | time: 0.093s
# | RMSProp | epoch: 051 | loss: 4.35205 -- iter: 58/58
# --
# Training Step: 52  | total loss: 4.35173 | time: 0.090s
# | RMSProp | epoch: 052 | loss: 4.35173 -- iter: 58/58
# --
# Training Step: 53  | total loss: 4.35143 | time: 0.091s
# | RMSProp | epoch: 053 | loss: 4.35143 -- iter: 58/58
# --
# Training Step: 54  | total loss: 4.35111 | time: 0.095s
# | RMSProp | epoch: 054 | loss: 4.35111 -- iter: 58/58
# --
# Training Step: 55  | total loss: 4.35078 | time: 0.092s
# | RMSProp | epoch: 055 | loss: 4.35078 -- iter: 58/58
# --
# Training Step: 56  | total loss: 4.35054 | time: 0.089s
# | RMSProp | epoch: 056 | loss: 4.35054 -- iter: 58/58
# --
# Training Step: 57  | total loss: 4.35025 | time: 0.093s
# | RMSProp | epoch: 057 | loss: 4.35025 -- iter: 58/58
# --
# Training Step: 58  | total loss: 4.35003 | time: 0.089s
# | RMSProp | epoch: 058 | loss: 4.35003 -- iter: 58/58
# --
# Training Step: 59  | total loss: 4.34974 | time: 0.091s
# | RMSProp | epoch: 059 | loss: 4.34974 -- iter: 58/58
# --
# Training Step: 60  | total loss: 4.34944 | time: 0.095s
# | RMSProp | epoch: 060 | loss: 4.34944 -- iter: 58/58
# --
# Training Step: 61  | total loss: 4.34900 | time: 0.089s
# | RMSProp | epoch: 061 | loss: 4.34900 -- iter: 58/58
# --
# Training Step: 62  | total loss: 4.34871 | time: 0.090s
# | RMSProp | epoch: 062 | loss: 4.34871 -- iter: 58/58
# --
# Training Step: 63  | total loss: 4.34825 | time: 0.087s
# | RMSProp | epoch: 063 | loss: 4.34825 -- iter: 58/58
# --
# Training Step: 64  | total loss: 4.34791 | time: 0.087s
# | RMSProp | epoch: 064 | loss: 4.34791 -- iter: 58/58
# --
# Training Step: 65  | total loss: 4.34751 | time: 0.088s
# | RMSProp | epoch: 065 | loss: 4.34751 -- iter: 58/58
# --
# Training Step: 66  | total loss: 4.34717 | time: 0.114s
# | RMSProp | epoch: 066 | loss: 4.34717 -- iter: 58/58
# --
# Training Step: 67  | total loss: 4.34657 | time: 0.120s
# | RMSProp | epoch: 067 | loss: 4.34657 -- iter: 58/58
# --
# Training Step: 68  | total loss: 4.34614 | time: 0.120s
# | RMSProp | epoch: 068 | loss: 4.34614 -- iter: 58/58
# --
# Training Step: 69  | total loss: 4.34560 | time: 0.101s
# | RMSProp | epoch: 069 | loss: 4.34560 -- iter: 58/58
# --
# Training Step: 70  | total loss: 4.34525 | time: 0.091s
# | RMSProp | epoch: 070 | loss: 4.34525 -- iter: 58/58
# --
# Training Step: 71  | total loss: 4.34468 | time: 0.100s
# | RMSProp | epoch: 071 | loss: 4.34468 -- iter: 58/58
# --
# Training Step: 72  | total loss: 4.34437 | time: 0.092s
# | RMSProp | epoch: 072 | loss: 4.34437 -- iter: 58/58
# --
# Training Step: 73  | total loss: 4.34383 | time: 0.100s
# | RMSProp | epoch: 073 | loss: 4.34383 -- iter: 58/58
# --
# Training Step: 74  | total loss: 4.34328 | time: 0.101s
# | RMSProp | epoch: 074 | loss: 4.34328 -- iter: 58/58
# --
# Training Step: 75  | total loss: 4.34268 | time: 0.099s
# | RMSProp | epoch: 075 | loss: 4.34268 -- iter: 58/58
# --
# Training Step: 76  | total loss: 4.34205 | time: 0.101s
# | RMSProp | epoch: 076 | loss: 4.34205 -- iter: 58/58
# --
# Training Step: 77  | total loss: 4.34152 | time: 0.106s
# | RMSProp | epoch: 077 | loss: 4.34152 -- iter: 58/58
# --
# Training Step: 78  | total loss: 4.34095 | time: 0.121s
# | RMSProp | epoch: 078 | loss: 4.34095 -- iter: 58/58
# --
# Training Step: 79  | total loss: 4.34040 | time: 0.138s
# | RMSProp | epoch: 079 | loss: 4.34040 -- iter: 58/58
# --
# Training Step: 80  | total loss: 4.33968 | time: 0.142s
# | RMSProp | epoch: 080 | loss: 4.33968 -- iter: 58/58
# --
# Training Step: 81  | total loss: 4.33913 | time: 0.095s
# | RMSProp | epoch: 081 | loss: 4.33913 -- iter: 58/58
# --
# Training Step: 82  | total loss: 4.33857 | time: 0.096s
# | RMSProp | epoch: 082 | loss: 4.33857 -- iter: 58/58
# --
# Training Step: 83  | total loss: 4.33806 | time: 0.090s
# | RMSProp | epoch: 083 | loss: 4.33806 -- iter: 58/58
# --
# Training Step: 84  | total loss: 4.33732 | time: 0.091s
# | RMSProp | epoch: 084 | loss: 4.33732 -- iter: 58/58
# --
# Training Step: 85  | total loss: 4.33658 | time: 0.095s
# | RMSProp | epoch: 085 | loss: 4.33658 -- iter: 58/58
# --
# Training Step: 86  | total loss: 4.33574 | time: 0.086s
# | RMSProp | epoch: 086 | loss: 4.33574 -- iter: 58/58
# --
# Training Step: 87  | total loss: 4.33519 | time: 0.086s
# | RMSProp | epoch: 087 | loss: 4.33519 -- iter: 58/58
# --
# Training Step: 88  | total loss: 4.33445 | time: 0.090s
# | RMSProp | epoch: 088 | loss: 4.33445 -- iter: 58/58
# --
# Training Step: 89  | total loss: 4.33348 | time: 0.086s
# | RMSProp | epoch: 089 | loss: 4.33348 -- iter: 58/58
# --
# Training Step: 90  | total loss: 4.33262 | time: 0.100s
# | RMSProp | epoch: 090 | loss: 4.33262 -- iter: 58/58
# --
# Training Step: 91  | total loss: 4.33181 | time: 0.094s
# | RMSProp | epoch: 091 | loss: 4.33181 -- iter: 58/58
# --
# Training Step: 92  | total loss: 4.33097 | time: 0.088s
# | RMSProp | epoch: 092 | loss: 4.33097 -- iter: 58/58
# --
# Training Step: 93  | total loss: 4.32981 | time: 0.093s
# | RMSProp | epoch: 093 | loss: 4.32981 -- iter: 58/58
# --
# Training Step: 94  | total loss: 4.32888 | time: 0.116s
# | RMSProp | epoch: 094 | loss: 4.32888 -- iter: 58/58
# --
# Training Step: 95  | total loss: 4.32778 | time: 0.100s
# | RMSProp | epoch: 095 | loss: 4.32778 -- iter: 58/58
# --
# Training Step: 96  | total loss: 4.32662 | time: 0.098s
# | RMSProp | epoch: 096 | loss: 4.32662 -- iter: 58/58
# --
# Training Step: 97  | total loss: 4.32555 | time: 0.112s
# | RMSProp | epoch: 097 | loss: 4.32555 -- iter: 58/58
# --
# Training Step: 98  | total loss: 4.32445 | time: 0.096s
# | RMSProp | epoch: 098 | loss: 4.32445 -- iter: 58/58
# --
# Training Step: 99  | total loss: 4.32324 | time: 0.091s
# | RMSProp | epoch: 099 | loss: 4.32324 -- iter: 58/58
# --
# Training Step: 100  | total loss: 4.32210 | time: 0.109s
# | RMSProp | epoch: 100 | loss: 4.32210 -- iter: 58/58
# --
# Training Step: 101  | total loss: 4.32065 | time: 0.102s
# | RMSProp | epoch: 101 | loss: 4.32065 -- iter: 58/58
# --
# Training Step: 102  | total loss: 4.31943 | time: 0.093s
# | RMSProp | epoch: 102 | loss: 4.31943 -- iter: 58/58
# --
# Training Step: 103  | total loss: 4.31819 | time: 0.100s
# | RMSProp | epoch: 103 | loss: 4.31819 -- iter: 58/58
# --
# Training Step: 104  | total loss: 4.31709 | time: 0.105s
# | RMSProp | epoch: 104 | loss: 4.31709 -- iter: 58/58
# --
# Training Step: 105  | total loss: 4.31580 | time: 0.093s
# | RMSProp | epoch: 105 | loss: 4.31580 -- iter: 58/58
# --
# Training Step: 106  | total loss: 4.31408 | time: 0.103s
# | RMSProp | epoch: 106 | loss: 4.31408 -- iter: 58/58
# --
# Training Step: 107  | total loss: 4.31225 | time: 0.120s
# | RMSProp | epoch: 107 | loss: 4.31225 -- iter: 58/58
# --
# Training Step: 108  | total loss: 4.31034 | time: 0.115s
# | RMSProp | epoch: 108 | loss: 4.31034 -- iter: 58/58
# --
# Training Step: 109  | total loss: 4.30815 | time: 0.109s
# | RMSProp | epoch: 109 | loss: 4.30815 -- iter: 58/58
# --
# Training Step: 110  | total loss: 4.30626 | time: 0.114s
# | RMSProp | epoch: 110 | loss: 4.30626 -- iter: 58/58
# --
# Training Step: 111  | total loss: 4.30419 | time: 0.121s
# | RMSProp | epoch: 111 | loss: 4.30419 -- iter: 58/58
# --
# Training Step: 112  | total loss: 4.30165 | time: 0.094s
# | RMSProp | epoch: 112 | loss: 4.30165 -- iter: 58/58
# --
# Training Step: 113  | total loss: 4.29919 | time: 0.091s
# | RMSProp | epoch: 113 | loss: 4.29919 -- iter: 58/58
# --
# Training Step: 114  | total loss: 4.29627 | time: 0.131s
# | RMSProp | epoch: 114 | loss: 4.29627 -- iter: 58/58
# --
# Training Step: 115  | total loss: 4.29360 | time: 0.130s
# | RMSProp | epoch: 115 | loss: 4.29360 -- iter: 58/58
# --
# Training Step: 116  | total loss: 4.29035 | time: 0.174s
# | RMSProp | epoch: 116 | loss: 4.29035 -- iter: 58/58
# --
# Training Step: 117  | total loss: 4.28582 | time: 0.114s
# | RMSProp | epoch: 117 | loss: 4.28582 -- iter: 58/58
# --
# Training Step: 118  | total loss: 4.28174 | time: 0.116s
# | RMSProp | epoch: 118 | loss: 4.28174 -- iter: 58/58
# --
# Training Step: 119  | total loss: 4.27690 | time: 0.102s
# | RMSProp | epoch: 119 | loss: 4.27690 -- iter: 58/58
# --
# Training Step: 120  | total loss: 4.26943 | time: 0.110s
# | RMSProp | epoch: 120 | loss: 4.26943 -- iter: 58/58
# --
# Training Step: 121  | total loss: 4.26109 | time: 0.103s
# | RMSProp | epoch: 121 | loss: 4.26109 -- iter: 58/58
# --
# Training Step: 122  | total loss: 4.24937 | time: 0.101s
# | RMSProp | epoch: 122 | loss: 4.24937 -- iter: 58/58
# --
# Training Step: 123  | total loss: 4.23295 | time: 0.143s
# | RMSProp | epoch: 123 | loss: 4.23295 -- iter: 58/58
# --
# Training Step: 124  | total loss: 4.21211 | time: 0.111s
# | RMSProp | epoch: 124 | loss: 4.21211 -- iter: 58/58
# --
# Training Step: 125  | total loss: 4.19223 | time: 0.100s
# | RMSProp | epoch: 125 | loss: 4.19223 -- iter: 58/58
# --
# Training Step: 126  | total loss: 4.16782 | time: 0.092s
# | RMSProp | epoch: 126 | loss: 4.16782 -- iter: 58/58
# --
# Training Step: 127  | total loss: 4.14222 | time: 0.094s
# | RMSProp | epoch: 127 | loss: 4.14222 -- iter: 58/58
# --
# Training Step: 128  | total loss: 4.11545 | time: 0.137s
# | RMSProp | epoch: 128 | loss: 4.11545 -- iter: 58/58
# --
# After pruning: 16 notes
# After pruning: 12 notes
# After pruning: 14 notes
# After pruning: 13 notes
# After pruning: 12 notes
# After pruning: 9 notes
# After pruning: 15 notes
# After pruning: 12 notes
# After pruning: 14 notes
# After pruning: 14 notes
# After pruning: 13 notes
# After pruning: 13 notes
# After pruning: 13 notes
# After pruning: 15 notes
# After pruning: 13 notes
# After pruning: 12 notes
# After pruning: 11 notes
# After pruning: 14 notes

# %% [markdown]
# You can play generated sample using any midi player
#
# Under linux I prefer timidity

# %%
# !! timidity midi/deepjazz_on_metheny...128_epochs.midi
# Out:
# ['Check URL type=7',
#  'Check URL type=2',
#  'Check URL type=1',
#  'open url (type=1, name=/usr/local/Cellar/timidity/2.14.0/share/timidity/timidity.cfg)',
#  'url_file_open(/usr/local/Cellar/timidity/2.14.0/share/timidity/timidity.cfg)',
#  'mmap - success. size=4625',
#  'Check URL type=7',
#  'Check URL type=2',
#  'Check URL type=1',
#  'open url (type=1, name=~/.timidity.cfg)',
#  'url_file_open(~/.timidity.cfg)',
#  'Playing midi/deepjazz_on_metheny...128_epochs.midi',
#  'MIDI file: midi/deepjazz_on_metheny...128_epochs.midi',
#  'Check URL type=7',
#  'Check URL type=2',
#  'Check URL type=1',
#  'open url (type=1, name=midi/deepjazz_on_metheny...128_epochs.midi)',
#  'url_file_open(midi/deepjazz_on_metheny...128_epochs.midi)',
#  'Check URL type=7',
#  'Check URL type=2',
#  'Check URL type=1',
#  'open url (type=1, name=/usr/local/Cellar/timidity/2.14.0/share/timidity/midi/deepjazz_on_metheny...128_epochs.midi)',
#  'url_file_open(/usr/local/Cellar/timidity/2.14.0/share/timidity/midi/deepjazz_on_metheny...128_epochs.midi)',
#  'midi/deepjazz_on_metheny...128_epochs.midi: No such file or directory']
